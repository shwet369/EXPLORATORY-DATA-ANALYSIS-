# %% [markdown]
# - cv computer vision
# - Deep learning
# - Read any image and video

# %% [markdown]
# #### Reading the data

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
#file folder 
#file name
#file extention
file_loc=pd.read_csv("C:\\Users\\SHWETA BHOYAR\\OneDrive\\Documents\\New folder\\Omkar sir PYTHON\\Full Stack Data Science @ 7_15 AM _ Mr.Omkar [6th Dec] Mr.Omkar-20231223T183622Z-001\\Excel data set\Visadataset.csv")

# %%
file_loc
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - Folder name should be downlod
# - Unicode error
# - File not found error
# - permission error (partially)

# %%
bank_data = "C:\\User""s\\SHWETA BHOYAR\\OneDrive\\Documents\\New folder\\Omkar sir PYTHON\\Full Stack Data Science @ 7_15 AM _ Mr.Omkar [6th Dec] Mr.Omkar-20231223T183622Z-001\\Excel data set\\bank.csv"

# %%
pd.read_csv(bank_data,sep=";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# - How to create dataframe
# - hOW to add columns
# - How to add row
# - How to drop columns
# - How to save the documents

# %% [markdown]
# Method 1

# %% [markdown]
# *Create dataframe using list*

# %% [markdown]
# step-1

# %%
#Create a dataframe 
Name= ['Ramesh','Suresh','Satish']
Age= [20,30,40]
pd.DataFrame(zip(Name,Age))
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  30
# 2  Satish  40

# %% [markdown]
# step- 2
# - Update the columns name

# %%
Nme=['Ramesh','suresh','satish']
Age= [20,30,40]
df1=pd.DataFrame(zip(Name,Age))
df1
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  30
# 2  Satish  40

# %% [markdown]
# Step-3
# Update the index

# %%
Name=['Ramesh','suresh','satish']
Age=[20,30,40]
df1=pd.DataFrame(zip(Nme,Age),
                columns=['Name','Age'],
                index=['A','B','C'])
df1
# Out:
#      Name  Age
# A  Ramesh   20
# B  suresh   30
# C  satish   40

# %% [markdown]
# Step 4
# - change the entire column data

# %%
df1['Name']=['Satish','Suresh','Ramesh']
df1
# Out:
#      Name  Age
# A  Satish   20
# B  Suresh   30
# C  Ramesh   40

# %% [markdown]
# step 5
# - Create a new columns

# %%
df1['City']=['Hyd','Mumbai','Chennai']
df1
# Out:
#      Name  Age     City
# A  Satish   20      Hyd
# B  Suresh   30   Mumbai
# C  Ramesh   40  Chennai

# %%
# Change the index A B C to 0 1 2
df1=pd.DataFrame(zip(Name,Age),
columns=['Name','Age'],
index=[0,1,2])
df1
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  suresh   30
# 2  satish   40

# %%
len(df1.index)
# Out:
# 3

# %%
df1.loc[3]=['Alex',35]

# %%
df1
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  suresh   30
# 2  satish   40
# 3    Alex   35

# %%
df1.loc[4]=['Bunny',47]

# %%
df1
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  suresh   30
# 2  satish   40
# 3    Alex   35
# 4   Bunny   47

# %% [markdown]
# Step 7
# - Drop the column
# - Before drop the column
# - i will create new column
# - i have only two column are there Name and Age
# - i will create a city, then i will drop that

# %%
Name=['Ramesh','Suresh','Sathish']
Age=[20,25,30]
df1=pd.DataFrame(zip(Name,Age),
                 columns=['Names','Age'],
                 index=[0,1,2])
df1['City']=['Hyd','Blr','Chennai']
df1
# Out:
#      Names  Age     City
# 0   Ramesh   20      Hyd
# 1   Suresh   25      Blr
# 2  Sathish   30  Chennai

# %%
# Axis=1 It reference Column
# Axis=0 It reference rows
# The result You want to overwrite or save in another variable
df1.drop('City',
axis=1,
inplace=True)

# %%
df1
# Out:
#      Names  Age
# 0   Ramesh   20
# 1   Suresh   25
# 2  Sathish   30

# %% [markdown]
# step-8
#
# *Drop the rows*

# %%
df1.drop(2,inplace=True)

# %%
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25

# %% [markdown]
# $step-9$
#
# **save the  df1 in local**

# %%
Name= ['Ramesh','Suresh','Satish']
Age= [20,30,40]
df1=pd.DataFrame(zip(Name,Age),
                columns=['Name','Age'],
                index=[0,1,2])
df1['City']=['Hyd','Blr','Chennai']
df1
# Out:
#      Name  Age     City
# 0  Ramesh   20      Hyd
# 1  Suresh   30      Blr
# 2  Satish   40  Chennai

# %%
df1.drop('City',axis=1,inplace=True)
df1
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  Suresh   30
# 2  Satish   40

# %%
df1.drop(2,inplace=True)
df1
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  Suresh   30

# %%
# Read data file is seperate folder
# you need to provide path
# Write the output in seperate folder
# you need to provide path
#folder location + name of the file + extension
import os

# %%
df1.to_csv("C:\\Users\\SHWETA BHOYAR\\OneDrive\\Documents\\New folder\\Omkar sir PYTHON\\Full Stack Data Science @ 7_15 AM _ Mr.Omkar [6th Dec] Mr.Omkar-20231223T183622Z-001\\Excel data set\\sample1.csv", index=False)

# %%
pd.read_csv('C:\\Users\\SHWETA BHOYAR\\OneDrive\\Documents\\New folder\\Omkar sir PYTHON\\Full Stack Data Science @ 7_15 AM _ Mr.Omkar [6th Dec] Mr.Omkar-20231223T183622Z-001\\Excel data set\\sample1.csv')
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  Suresh   30

# %%
# Same folder
df1.to_csv("output1.csv",index=False)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SHWETA BHOYAR\\OneDrive\\python practice set\\EDA SET'

# %%
# Same folder
pd.read_csv("output1.csv")
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  Suresh   30

# %% [markdown]
# Method-2
# - Create a DataFrame using dictionary

# %%
d1={'Name':['Ramesh','Suresh','Satish'],
   'Age':[20,30,40]}
d1
#Key values considerd columns name
#values considerd a rows
# Out:
# {'Name': ['Ramesh', 'Suresh', 'Satish'], 'Age': [20, 30, 40]}

# %%
pd.DataFrame(d1)
# Out:
#      Name  Age
# 0  Ramesh   20
# 1  Suresh   30
# 2  Satish   40

# %%
l1=['Ramesh','Suresh','Sathish']
l2=[20,25,30]
pd.DataFrame(zip(l1,l2))
# Out:
#          0   1
# 0   Ramesh  20
# 1   Suresh  25
# 2  Sathish  30

# %% [markdown]
# *Method − 3*

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import random
even_list=[]
for i in range(5):
    num=random.randint(20,50)
    if num%2==0:
        even_list.append(num)
even_list
# Out:
# [34, 36, 20]

# %%
df1['Even']=even_list

# %%
df1['Odd']=[1,3,5]

# %%
df1
# Out:
#    Even  Odd
# 0    34    1
# 1    36    3
# 2    20    5
