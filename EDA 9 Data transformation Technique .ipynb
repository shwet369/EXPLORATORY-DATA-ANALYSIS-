# %% [markdown]
# *Data Transformation Techniques*
# - Generally used for to convert Normal distribution
# - Because all statistical math analysis by assumption Data follows Normal distribution
# - It is also avoid skew ness also
# - We have some important transformation
#     - Log transformation
#     - Exponential transformation
#     - Reciprocal transformation
# - Square root transformation
# - Power transformaton

# %%
#Read the required packages
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the data
#Exponential − data
exp_data=np.random.exponential(size=10000)
exp_data[:10]
# We are consider exponential data set with random 1k observations
# using numpy package
# Out:
# array([0.34693699, 1.78180528, 1.41940635, 1.15265344, 1.49879806,
#        1.7054346 , 0.23125806, 0.1022492 , 2.41711663, 0.17577805])

# %%
plt.hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# Norm − data

# %%
norm_data=np.random.normal(size=1000)
plt.hist(norm_data)
# Out:
# (array([  7.,  31.,  82., 184., 258., 237., 145.,  45.,   9.,   2.]),
#  array([-3.03051262, -2.3938322 , -1.75715178, -1.12047136, -0.48379094,
#          0.15288947,  0.78956989,  1.42625031,  2.06293073,  2.69961115,
#          3.33629157]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - Step − 3
#
# *Log Transformaton*
# - np.log is used for log transformation
# - Generally log transformation will not convert data into normal
# - It avoids skew ness
# - np.log means natural logorithm base=e

# %%
log_data=np.log(exp_data)
log_data[:10]
# Out:
# array([-1.0586121 ,  0.57762705,  0.35023872,  0.14206662,  0.40466349,
#         0.53381998, -1.46422105, -2.28034233,  0.88257536, -1.73853316])

# %%
exp_data[:10]
# Out:
# array([0.34693699, 1.78180528, 1.41940635, 1.15265344, 1.49879806,
#        1.7054346 , 0.23125806, 0.1022492 , 2.41711663, 0.17577805])

# %%
plt.hist(log_data,bins=40,label='Log data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
bins=40,

label='Exponential')

plt.legend()
plt.subplot(1,2,2).hist(log_data,
bins=40,

label='Log Transformation')

plt.legend()
plt.show()

# %% [markdown]
# - Step − 4
#
# *Reciprocal transformation*
# - Reciprocal transformation fails when data has zero value

# %%
# Take the exponential data
# rec_data= 1/exp_data
# plot the histogram and check it
rec_data=np.reciprocal(exp_data)
plt.hist(rec_data,bins=40,label='Reciprocal Data')
plt.legend()
plt.show()

# %%
exp_data[:2]
# Out:
# array([0.34693699, 1.78180528])

# %%
1/1.687,1/0.88
# Out:
# (0.5927682276229994, 1.1363636363636365)

# %% [markdown]
# step-5
#
# *Square root transformation*

# %%
print(25**2) # square,
print(25**(1/2)) # square root
print(np.sqrt(25))
# Out:
# 625
# 5.0
# 5.0

# %%
sqrt_data=np.sqrt(exp_data)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
bins=40,

label='Exponential')

plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,
bins=40,

label='Sqaure root Transformation')

plt.legend()
plt.show()

# %%
import seaborn as sns 
sns.distplot(sqrt_data)
# Out:
# C:\Users\SHWETA BHOYAR\AppData\Local\Temp\ipykernel_22900\226066130.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sqrt_data)
# <Axes: ylabel='Density'>

# %% [markdown]
# step-6
# *Power transformer*
#
# - it is related to sklearn package
# -  package name: sklern.preprocessing
# -    method name: power transform
# - inside box-cox, yeo-jhonson

# %%
exp_data
# Out:
# array([0.34693699, 1.78180528, 1.41940635, ..., 0.77552408, 1.87535991,
#        1.2326889 ])

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
#pt_data=pt.fit([exp_data]).transform([exp_data])

# %%
#pt.data

# %%
plt.hist(pt_data[0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 plt.hist(pt_data[0])
#       2 plt.show()
#
# NameError: name 'pt_data' is not defined
